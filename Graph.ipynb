# %%
import matplotlib.pyplot as plt
import csv
from pylab import rcParams

x = []
y = []

with open('pi8.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(int(row[0]))
        y.append(float(row[1]))

plt.plot(x,y, label='For t = $\pi/8$')

x1 = []
y1 = []

with open('pi10.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x1.append(int(row[0]))
        y1.append(float(row[1]))

plt.plot(x1,y1, label='For t = $\pi/10$', color = 'b')

x2 = []
y2 = []

with open('pi12.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x2.append(int(row[0]))
        y2.append(float(row[1]))

plt.plot(x2,y2, label='For t = $\pi/12$', color = 'c')

x3 = []
y3 = []

with open('pi14.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x3.append(int(row[0]))
        y3.append(float(row[1]))

plt.plot(x3,y3, label='For t = $\pi/14$', color = 'm')

x4 = []
y4 = []

with open('pi16.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x4.append(int(row[0]))
        y4.append(float(row[1]))
plt.plot(x4,y4, label='For t = $\pi/16$', color = 'k')

x5 = []
y5 = []

with open('ones.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x5.append(int(row[0]))
        y5.append(float(row[1]))
plt.plot(x5,y5, label='Probability = 1', color = 'r')

rcParams['figure.figsize'] = 12, 6

plt.xlim((0,100))
plt.xlabel('Number of Layers')
plt.ylabel('Probability of getting state 1110')
plt.title('Graph of probability of getting state 1110 with increasing layers of 1st order Suzuki Trotter')
plt.legend()
plt.show()
